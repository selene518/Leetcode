# %% [markdown]
# <a href="https://colab.research.google.com/github/selene518/Leetcode/blob/main/Leetcode_177_Nth_Highest_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

def nth_highest_salary(employee: pd.DataFrame, N: int) -> pd.DataFrame:
  employee['rank'] = employee['salary'].rank(method='dense', ascending=False)
  nthhighest = employee[employee['rank'] == N]
  return pd.DataFrame({f'getNthHighestSalary({N})'：[None if len(nthhighest) == 0
                                                    else nthhighest['salary'].iloc[0]]})
