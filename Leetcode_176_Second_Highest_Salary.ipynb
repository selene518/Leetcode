# %% [markdown]
# <a href="https://colab.research.google.com/github/selene518/Leetcode/blob/main/Leetcode_176_Second_Highest_Salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

def second_highest_salary(employee: pd.DataFrame) -> pd.DataFrame:
  employee['rank'] = employee['salary'].rank(menthod='dense', ascending=False)
  second = employee[employee['rank']==2]
  return pd.DataFrame({'SecondHighestSalary':[None if len(second)==0 else second['salary'].iloc[0]]})
